# %% [markdown]
# # 🚀 Lecture Notes: Section 1 — What is AI?
#
# Graduate-level handout with explanations, equations, and academic-style diagrams.

# %% [markdown]
# ## 1.1 Definitions of AI
# AI can be classified along two dimensions (Human vs Rational, Thinking vs Acting).

# %% [markdown]
# ![AIMA Definitions Quadrant](data:image/png;base64,...)

# %% [markdown]
# - **Thinking Humanly**: Mimicking human thought (e.g., SOAR, ACT-R).
# - **Acting Humanly**: Turing Test — imitate human behavior (e.g., chatbots).
# - **Thinking Rationally**: Using logic/laws of thought (e.g., theorem provers).
# - **Acting Rationally**: Rational agent paradigm (AIMA) — agents that maximize performance.

# %% [markdown]
# ## 1.2 Formal Definition of a Rational Agent

# %% [markdown]
# An agent is defined by its **agent function**:
#
# \[ f: P^* \rightarrow A \]
#
# - \(P^*\) = set of all percept sequences
# - \(A\) = set of possible actions
#
# A rational agent selects action \(a_t\):
#
# \[ a_t = \arg\max_{a \in A} \; \mathbb{E}[U \mid percept\_history] \]
#
# Where:
# - \(U\) = performance measure (utility)
# - Expectation is over possible environment states

# %% [markdown]
# ![Rational Agent Loop](data:image/png;base64,...)

# %% [markdown]
# ## 1.3 AI Spectrum

# %% [markdown]
# ![AI Spectrum](data:image/png;base64,...)

# %% [markdown]
# - **Narrow AI (Weak AI):** Domain-specific (e.g., AlphaGo, Siri).
# - **General AI (Strong AI):** Hypothetical, human-level.
# - **Superintelligence:** Beyond human capability (debated).

# %% [markdown]
# ## 1.4 Interdisciplinary Nature of AI
# AI draws from: Mathematics, Computer Science, Cognitive Science, Neuroscience, Philosophy.

# %% [markdown]
# ## 1.5 Industry Case Study — Amazon Hiring AI
# Amazon’s AI recruiting tool was scrapped because it **learned gender bias** from historical hiring data. Shows AI hype vs reality.

# %% [markdown]
# ## 1.6 Misconceptions
# - AI is **not conscious** (LLMs predict, don’t understand).
# - AI is **not infallible** (can amplify biases).
# - AI is **not fully replacing humans** (mostly augmenting).

# %% [markdown]
# ## 1.7 Discussion Prompt
# 💬 *Should AI be defined by its **behavior** (outcomes) or its **internal reasoning processes**?*
