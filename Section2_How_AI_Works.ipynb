# %% [markdown]
# # 🚀 Lecture Notes: Section 2 — How AI Works
#
# Graduate-level explanations with diagrams (academic style).

# %% [markdown]
# ## 2.1 The AI Cycle
# AI systems operate in a loop: Perception → Reasoning → Decision → Action → Feedback.

# %% [markdown]
# ![AI Cycle Loop](data:image/png;base64,...)

# %% [markdown]
# ## 2.2 Core Components of AI Systems
# - **Knowledge Representation** (logic, knowledge graphs)
# - **Reasoning & Inference** (deductive, inductive, probabilistic)
# - **Learning** (supervised, unsupervised, reinforcement)
# - **Planning & Decision Making** (search, optimization, MDPs)
# - **Perception** (vision, NLP, sensors)
# - **Action** (robotics, digital actions)

# %% [markdown]
# ## 2.3 The AI Pipeline
# Step-by-step: Data → Preprocessing → Modeling → Evaluation → Deployment → Feedback.

# %% [markdown]
# ![AI Pipeline](data:image/png;base64,...)

# %% [markdown]
# ## 2.4 Subfields of AI (AIMA Classification)
# - Problem Solving & Search
# - Knowledge & Reasoning
# - Machine Learning
# - Perception
# - Robotics
# - Human-AI Interaction

# %% [markdown]
# ## 2.5 Example: Self-driving Car

# %% [markdown]
# ![Self-driving Car Schematic](data:image/png;base64,...)

# %% [markdown]
# Workflow:
# 1. **Perception**: Sensors detect environment.
# 2. **Reasoning**: Predict other agents' behavior.
# 3. **Decision**: Choose safest maneuver.
# 4. **Action**: Control steering, braking.
# 5. **Learning**: Improve with experience/fleet data.

# %% [markdown]
# ## 2.6 Challenges
# - Data dependency
# - Explainability (black-box models)
# - Scalability
# - Ethics & fairness

# %% [markdown]
# ## 2.7 Discussion Prompt
# 💬 *Should AI prioritize explainability (transparency) or accuracy (even if black-box)?*
