# %% [markdown]
# # 🚀 Lecture Notes: Section 5 — Applications of AI
#
# Overview of major domains where AI is applied.

# %% [markdown]
# ## 5.1 Healthcare
# - Medical imaging (AI-assisted radiology)
# - Drug discovery (DeepMind’s AlphaFold)
# - Virtual health assistants
# - Predictive analytics for patient care

# %% [markdown]
# ## 5.2 Finance
# - Fraud detection
# - Algorithmic trading
# - Credit scoring
# - Customer service chatbots

# %% [markdown]
# ## 5.3 Transportation
# - Autonomous vehicles (self-driving cars, drones)
# - Traffic management systems
# - Route optimization
# - Predictive maintenance of vehicles

# %% [markdown]
# ## 5.4 Retail
# - Recommendation systems (Amazon, Netflix)
# - Inventory management
# - Personalized marketing
# - Chatbots for customer support

# %% [markdown]
# ## 5.5 Education
# - Intelligent tutoring systems
# - Automated grading
# - Personalized learning paths
# - Plagiarism detection

# %% [markdown]
# ## 5.6 Agriculture
# - Precision farming
# - Crop monitoring with drones
# - Soil analysis and yield prediction
# - Automated irrigation systems

# %% [markdown]
# ## 5.7 Applications Wheel

# %% [markdown]
# ![Applications of AI](data:image/png;base64,...)

# %% [markdown]
# ## 5.8 Discussion Prompt
# 💬 *Which application of AI do you think will have the greatest social impact in the next 10 years? Why?*
